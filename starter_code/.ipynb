# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\man-y\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\man-y\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import csv
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# create the dataframe to hold city info
cities_df = pd.DataFrame({"City":cities})
cities_df['Lat'] = ''
cities_df['Lng'] = ''
cities_df['Max Temp'] = ''
cities_df['Humidity'] = ''
cities_df['Cloudiness'] = ''
cities_df['Wind Speed'] = ''
cities_df['Country'] = ''
cities_df['Date'] = ''

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 1

# create the lists to hold the data for each city
city_list = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []




for city in cities:    
        # setup url and make API request
        print(f"City log {count} of Set 1 | {city}.")
        count = count + 1
        
        target_url = ("http://api.openweathermap.org/data/2.5/weather?"
                      'appid={0}&q={1}').format(weather_api_key,city)
        try:
            # extract results
            response = requests.get(target_url).json()
            
            # add the city info to the lists             
            city_list.append(response['name'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            humidity.append(response['main']['humidity'])
            cloudiness.append(response['clouds']['all'])
            wind_speed.append(response['wind']['speed'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
           
           
           
            
        except:
            print("City and associated data missing")
# Out:
# City log 1 of Set 1 | port-de-bouc.
# City log 2 of Set 1 | kajaani.
# City log 3 of Set 1 | busselton.
# City log 4 of Set 1 | sentyabrskiy.
# City and associated data missing
# City log 5 of Set 1 | coihaique.
# City log 6 of Set 1 | constitucion.
# City log 7 of Set 1 | severo-kurilsk.
# City log 8 of Set 1 | tabiauea.
# City and associated data missing
# City log 9 of Set 1 | hermanus.
# City log 10 of Set 1 | bambous virieux.
# City log 11 of Set 1 | clyde river.
# City log 12 of Set 1 | hilo.
# City log 13 of Set 1 | mataura.
# City log 14 of Set 1 | toliary.
# City and associated data missing
# City log 15 of Set 1 | illoqqortoormiut.
# City and associated data missing
# City log 16 of Set 1 | buzmeyin.
# City log 17 of Set 1 | taitung.
# City log 18 of Set 1 | san andres.
# City log 19 of Set 1 | haines junction.
# City log 20 of Set 1 | svetlogorsk.
# City log 21 of Set 1 | georgetown.
# City log 22 of Set 1 | talnakh.
# City log 23 of Set 1 | lake city.
# City log 24 of Set 1 | taolanaro.
# City and associated data missing
# City log 25 of Set 1 | bluff.
# City log 26 of Set 1 | inderborskiy.
# City and associated data missing
# City log 27 of Set 1 | qaanaaq.
# City log 28 of Set 1 | jamestown.
# City log 29 of Set 1 | esperance.
# City log 30 of Set 1 | rikitea.
# City log 31 of Set 1 | nikolskoye.
# City log 32 of Set 1 | isangel.
# City log 33 of Set 1 | dayong.
# City log 34 of Set 1 | camana.
# City log 35 of Set 1 | luau.
# City log 36 of Set 1 | klaksvik.
# City log 37 of Set 1 | yetholm.
# City and associated data missing
# City log 38 of Set 1 | arraial do cabo.
# City log 39 of Set 1 | sinnamary.
# City log 40 of Set 1 | airai.
# City log 41 of Set 1 | plettenberg bay.
# City log 42 of Set 1 | chuy.
# City log 43 of Set 1 | portland.
# City log 44 of Set 1 | lolua.
# City and associated data missing
# City log 45 of Set 1 | albany.
# City log 46 of Set 1 | kutum.
# City log 47 of Set 1 | roswell.
# City log 48 of Set 1 | salinas.
# City log 49 of Set 1 | juarez.
# City log 50 of Set 1 | vaini.
# City log 51 of Set 1 | karatau.
# City log 52 of Set 1 | bredasdorp.
# City log 53 of Set 1 | borogontsy.
# City log 54 of Set 1 | mys shmidta.
# City and associated data missing
# City log 55 of Set 1 | punta arenas.
# City log 56 of Set 1 | kapaa.
# City log 57 of Set 1 | lebu.
# City log 58 of Set 1 | trairi.
# City log 59 of Set 1 | gat.
# City log 60 of Set 1 | udachnyy.
# City log 61 of Set 1 | taoudenni.
# City log 62 of Set 1 | lorengau.
# City log 63 of Set 1 | aflu.
# City and associated data missing
# City log 64 of Set 1 | saleaula.
# City and associated data missing
# City log 65 of Set 1 | nanortalik.
# City log 66 of Set 1 | college.
# City log 67 of Set 1 | shenkursk.
# City log 68 of Set 1 | belushya guba.
# City and associated data missing
# City log 69 of Set 1 | cape town.
# City log 70 of Set 1 | ushuaia.
# City log 71 of Set 1 | kodiak.
# City log 72 of Set 1 | bethel.
# City log 73 of Set 1 | whitianga.
# City log 74 of Set 1 | george.
# City log 75 of Set 1 | hvolsvollur.
# City log 76 of Set 1 | abancay.
# City log 77 of Set 1 | madhupur.
# City log 78 of Set 1 | cockburn town.
# City log 79 of Set 1 | butaritari.
# City log 80 of Set 1 | puerto escondido.
# City log 81 of Set 1 | new norfolk.
# City log 82 of Set 1 | cherskiy.
# City log 83 of Set 1 | tasiilaq.
# City log 84 of Set 1 | saint-philippe.
# City log 85 of Set 1 | port elizabeth.
# City log 86 of Set 1 | muroto.
# City log 87 of Set 1 | yulara.
# City log 88 of Set 1 | pevek.
# City log 89 of Set 1 | port lincoln.
# City log 90 of Set 1 | upernavik.
# City log 91 of Set 1 | tuktoyaktuk.
# City log 92 of Set 1 | yarkovo.
# City log 93 of Set 1 | gazli.
# City log 94 of Set 1 | moses lake.
# City log 95 of Set 1 | villazon.
# City log 96 of Set 1 | daru.
# City log 97 of Set 1 | mount isa.
# City log 98 of Set 1 | saskylakh.
# City log 99 of Set 1 | norman wells.
# City log 100 of Set 1 | avarua.
# City log 101 of Set 1 | grand-lahou.
# City log 102 of Set 1 | outlook.
# City log 103 of Set 1 | carnarvon.
# City log 104 of Set 1 | kysyl-syr.
# City log 105 of Set 1 | alice town.
# City log 106 of Set 1 | pyapon.
# City log 107 of Set 1 | doha.
# City log 108 of Set 1 | port alfred.
# City log 109 of Set 1 | huarmey.
# City log 110 of Set 1 | kaliningrad.
# City log 111 of Set 1 | barrow.
# City log 112 of Set 1 | burnie.
# City log 113 of Set 1 | kjollefjord.
# City log 114 of Set 1 | chokwe.
# City log 115 of Set 1 | bloomfield.
# City log 116 of Set 1 | saint anthony.
# City log 117 of Set 1 | samana.
# City log 118 of Set 1 | namibe.
# City log 119 of Set 1 | alice springs.
# City log 120 of Set 1 | castro.
# City log 121 of Set 1 | esmeraldas.
# City log 122 of Set 1 | trapani.
# City log 123 of Set 1 | karratha.
# City log 124 of Set 1 | naze.
# City log 125 of Set 1 | mazeikiai.
# City log 126 of Set 1 | mar del plata.
# City log 127 of Set 1 | ostrovnoy.
# City log 128 of Set 1 | tambura.
# City log 129 of Set 1 | albert.
# City log 130 of Set 1 | lompoc.
# City log 131 of Set 1 | luqiao.
# City log 132 of Set 1 | atuona.
# City log 133 of Set 1 | sorvag.
# City and associated data missing
# City log 134 of Set 1 | dikson.
# City log 135 of Set 1 | hobart.
# City log 136 of Set 1 | naples.
# City log 137 of Set 1 | tuatapere.
# City log 138 of Set 1 | brae.
# City log 139 of Set 1 | promysla.
# City and associated data missing
# City log 140 of Set 1 | ardakan.
# City log 141 of Set 1 | olafsvik.
# City log 142 of Set 1 | medea.
# City log 143 of Set 1 | yellowknife.
# City log 144 of Set 1 | hithadhoo.
# City log 145 of Set 1 | khatanga.
# City log 146 of Set 1 | kapit.
# City log 147 of Set 1 | victoria.
# City log 148 of Set 1 | thompson.
# City log 149 of Set 1 | thinadhoo.
# City log 150 of Set 1 | hambantota.
# City log 151 of Set 1 | veselynove.
# City log 152 of Set 1 | sioux lookout.
# City log 153 of Set 1 | yumen.
# City log 154 of Set 1 | fortuna.
# City log 155 of Set 1 | korla.
# City log 156 of Set 1 | howard springs.
# City log 157 of Set 1 | almaznyy.
# City log 158 of Set 1 | vaitape.
# City log 159 of Set 1 | geraldton.
# City log 160 of Set 1 | ponta do sol.
# City log 161 of Set 1 | vardo.
# City log 162 of Set 1 | puerto ayora.
# City log 163 of Set 1 | coolum beach.
# City log 164 of Set 1 | richards bay.
# City log 165 of Set 1 | lokosovo.
# City log 166 of Set 1 | nishihara.
# City log 167 of Set 1 | gorno-chuyskiy.
# City and associated data missing
# City log 168 of Set 1 | monrovia.
# City log 169 of Set 1 | bilma.
# City log 170 of Set 1 | satitoa.
# City and associated data missing
# City log 171 of Set 1 | east london.
# City log 172 of Set 1 | dinsor.
# City and associated data missing
# City log 173 of Set 1 | acapulco.
# City log 174 of Set 1 | qaqortoq.
# City log 175 of Set 1 | cabo san lucas.
# City log 176 of Set 1 | kasongo-lunda.
# City log 177 of Set 1 | saint-pierre.
# City log 178 of Set 1 | ohaba lunga.
# City and associated data missing
# City log 179 of Set 1 | nemuro.
# City log 180 of Set 1 | tofield.
# City log 181 of Set 1 | muravlenko.
# City log 182 of Set 1 | namwala.
# City log 183 of Set 1 | letterkenny.
# City log 184 of Set 1 | tucuman.
# City log 185 of Set 1 | ribeira grande.
# City log 186 of Set 1 | te anau.
# City log 187 of Set 1 | carutapera.
# City log 188 of Set 1 | vaitupu.
# City and associated data missing
# City log 189 of Set 1 | kruisfontein.
# City log 190 of Set 1 | sao joao da barra.
# City log 191 of Set 1 | turukhansk.
# City log 192 of Set 1 | arlit.
# City log 193 of Set 1 | krasnoselkup.
# City log 194 of Set 1 | kassala.
# City log 195 of Set 1 | touros.
# City log 196 of Set 1 | santa maria.
# City log 197 of Set 1 | mandalgovi.
# City log 198 of Set 1 | tsihombe.
# City and associated data missing
# City log 199 of Set 1 | katsuura.
# City log 200 of Set 1 | chagda.
# City and associated data missing
# City log 201 of Set 1 | tual.
# City log 202 of Set 1 | play cu.
# City and associated data missing
# City log 203 of Set 1 | riyadh.
# City log 204 of Set 1 | kaitangata.
# City log 205 of Set 1 | merrill.
# City log 206 of Set 1 | katsiveli.
# City and associated data missing
# City log 207 of Set 1 | luderitz.
# City log 208 of Set 1 | basoko.
# City log 209 of Set 1 | qasigiannguit.
# City log 210 of Set 1 | linguere.
# City log 211 of Set 1 | gaoua.
# City log 212 of Set 1 | attawapiskat.
# City and associated data missing
# City log 213 of Set 1 | inzhavino.
# City log 214 of Set 1 | lewisporte.
# City log 215 of Set 1 | fiumicino.
# City log 216 of Set 1 | harper.
# City log 217 of Set 1 | radcliff.
# City log 218 of Set 1 | rundu.
# City log 219 of Set 1 | pacific grove.
# City log 220 of Set 1 | eyl.
# City log 221 of Set 1 | port-gentil.
# City log 222 of Set 1 | okahandja.
# City log 223 of Set 1 | privolzhye.
# City log 224 of Set 1 | aklavik.
# City log 225 of Set 1 | otaru.
# City log 226 of Set 1 | villa oliva.
# City and associated data missing
# City log 227 of Set 1 | rio gallegos.
# City log 228 of Set 1 | iquique.
# City log 229 of Set 1 | xining.
# City log 230 of Set 1 | cayambe.
# City log 231 of Set 1 | jalu.
# City log 232 of Set 1 | takoradi.
# City log 233 of Set 1 | flinders.
# City log 234 of Set 1 | palmas.
# City log 235 of Set 1 | amderma.
# City and associated data missing
# City log 236 of Set 1 | ha.
# City and associated data missing
# City log 237 of Set 1 | vao.
# City log 238 of Set 1 | pisco.
# City log 239 of Set 1 | paamiut.
# City log 240 of Set 1 | barentsburg.
# City and associated data missing
# City log 241 of Set 1 | djougou.
# City log 242 of Set 1 | souillac.
# City log 243 of Set 1 | sumbawa.
# City and associated data missing
# City log 244 of Set 1 | vila velha.
# City log 245 of Set 1 | vysokogornyy.
# City log 246 of Set 1 | kalmunai.
# City log 247 of Set 1 | hofn.
# City log 248 of Set 1 | sao filipe.
# City log 249 of Set 1 | mahebourg.
# City log 250 of Set 1 | saldanha.
# City log 251 of Set 1 | leningradskiy.
# City log 252 of Set 1 | ust-tsilma.
# City log 253 of Set 1 | tiksi.
# City log 254 of Set 1 | hami.
# City log 255 of Set 1 | torbay.
# City log 256 of Set 1 | stawell.
# City log 257 of Set 1 | abha.
# City log 258 of Set 1 | kelvington.
# City log 259 of Set 1 | kirakira.
# City log 260 of Set 1 | mrirt.
# City and associated data missing
# City log 261 of Set 1 | ketchikan.
# City log 262 of Set 1 | aswan.
# City log 263 of Set 1 | fort thomas.
# City log 264 of Set 1 | nuuk.
# City log 265 of Set 1 | grindavik.
# City log 266 of Set 1 | luanda.
# City log 267 of Set 1 | innisfail.
# City log 268 of Set 1 | ternate.
# City log 269 of Set 1 | faya.
# City log 270 of Set 1 | hasaki.
# City log 271 of Set 1 | batticaloa.
# City log 272 of Set 1 | fort wellington.
# City log 273 of Set 1 | necochea.
# City log 274 of Set 1 | khonuu.
# City and associated data missing
# City log 275 of Set 1 | yuzawa.
# City log 276 of Set 1 | prince george.
# City log 277 of Set 1 | arroio grande.
# City log 278 of Set 1 | konakovo.
# City log 279 of Set 1 | pathein.
# City log 280 of Set 1 | youkounkoun.
# City log 281 of Set 1 | laguna.
# City log 282 of Set 1 | bagdarin.
# City log 283 of Set 1 | half moon bay.
# City log 284 of Set 1 | de-kastri.
# City log 285 of Set 1 | chara.
# City log 286 of Set 1 | provideniya.
# City log 287 of Set 1 | orlik.
# City log 288 of Set 1 | aloja.
# City log 289 of Set 1 | mayumba.
# City log 290 of Set 1 | berlevag.
# City log 291 of Set 1 | aitape.
# City log 292 of Set 1 | racale.
# City log 293 of Set 1 | ola.
# City log 294 of Set 1 | rungata.
# City and associated data missing
# City log 295 of Set 1 | hamilton.
# City log 296 of Set 1 | ust-kalmanka.
# City log 297 of Set 1 | valdivia.
# City log 298 of Set 1 | damghan.
# City log 299 of Set 1 | westport.
# City log 300 of Set 1 | bull savanna.
# City log 301 of Set 1 | camabatela.
# City log 302 of Set 1 | trelew.
# City log 303 of Set 1 | tautira.
# City log 304 of Set 1 | mnogovershinnyy.
# City log 305 of Set 1 | kloulklubed.
# City log 306 of Set 1 | iqaluit.
# City log 307 of Set 1 | chokurdakh.
# City log 308 of Set 1 | alyangula.
# City log 309 of Set 1 | samusu.
# City and associated data missing
# City log 310 of Set 1 | tamano.
# City log 311 of Set 1 | gizo.
# City log 312 of Set 1 | matara.
# City log 313 of Set 1 | abu samrah.
# City log 314 of Set 1 | kastrakion.
# City log 315 of Set 1 | ngukurr.
# City and associated data missing
# City log 316 of Set 1 | bengkulu.
# City log 317 of Set 1 | winnemucca.
# City log 318 of Set 1 | yarmouth.
# City log 319 of Set 1 | byron bay.
# City log 320 of Set 1 | guerrero negro.
# City log 321 of Set 1 | tuy hoa.
# City log 322 of Set 1 | broken hill.
# City log 323 of Set 1 | lukulu.
# City log 324 of Set 1 | barcelos.
# City log 325 of Set 1 | ponta pora.
# City log 326 of Set 1 | visnes.
# City log 327 of Set 1 | igrim.
# City log 328 of Set 1 | kailua.
# City log 329 of Set 1 | saint-joseph.
# City log 330 of Set 1 | tabou.
# City log 331 of Set 1 | mattru.
# City log 332 of Set 1 | grand river south east.
# City and associated data missing
# City log 333 of Set 1 | plastun.
# City log 334 of Set 1 | lagoa.
# City log 335 of Set 1 | andenes.
# City log 336 of Set 1 | kangaba.
# City log 337 of Set 1 | bilibino.
# City log 338 of Set 1 | langsa.
# City log 339 of Set 1 | san cristobal.
# City log 340 of Set 1 | longyearbyen.
# City log 341 of Set 1 | concepcion del uruguay.
# City log 342 of Set 1 | conakry.
# City log 343 of Set 1 | avera.
# City log 344 of Set 1 | port said.
# City log 345 of Set 1 | nome.
# City log 346 of Set 1 | saint george.
# City log 347 of Set 1 | saint-augustin.
# City log 348 of Set 1 | karaul.
# City and associated data missing
# City log 349 of Set 1 | borovichi.
# City log 350 of Set 1 | candawaga.
# City and associated data missing
# City log 351 of Set 1 | petit goave.
# City log 352 of Set 1 | faanui.
# City log 353 of Set 1 | batagay.
# City log 354 of Set 1 | dingzhou.
# City log 355 of Set 1 | ulaangom.
# City log 356 of Set 1 | sabang.
# City log 357 of Set 1 | kamenskoye.
# City and associated data missing
# City log 358 of Set 1 | inyonga.
# City log 359 of Set 1 | zheleznodorozhnyy.
# City log 360 of Set 1 | shieli.
# City log 361 of Set 1 | coquimbo.
# City log 362 of Set 1 | henties bay.
# City log 363 of Set 1 | ambilobe.
# City log 364 of Set 1 | monki.
# City log 365 of Set 1 | varde.
# City log 366 of Set 1 | port augusta.
# City log 367 of Set 1 | sur.
# City log 368 of Set 1 | babu.
# City log 369 of Set 1 | lata.
# City log 370 of Set 1 | gilgit.
# City log 371 of Set 1 | jumla.
# City log 372 of Set 1 | codrington.
# City log 373 of Set 1 | broome.
# City log 374 of Set 1 | halalo.
# City and associated data missing
# City log 375 of Set 1 | san patricio.
# City log 376 of Set 1 | mosquera.
# City log 377 of Set 1 | tagusao.
# City log 378 of Set 1 | ust-kut.
# City log 379 of Set 1 | beloha.
# City log 380 of Set 1 | strezhevoy.
# City log 381 of Set 1 | awbari.
# City log 382 of Set 1 | gourcy.
# City log 383 of Set 1 | sao felix do xingu.
# City log 384 of Set 1 | svetlyy.
# City log 385 of Set 1 | diego de almagro.
# City log 386 of Set 1 | cidreira.
# City log 387 of Set 1 | salalah.
# City log 388 of Set 1 | fare.
# City log 389 of Set 1 | biak.
# City log 390 of Set 1 | satana.
# City log 391 of Set 1 | faranah.
# City log 392 of Set 1 | shingu.
# City log 393 of Set 1 | skjervoy.
# City log 394 of Set 1 | alofi.
# City log 395 of Set 1 | margate.
# City log 396 of Set 1 | narsaq.
# City log 397 of Set 1 | yendi.
# City log 398 of Set 1 | kieta.
# City log 399 of Set 1 | surt.
# City log 400 of Set 1 | mayo.
# City log 401 of Set 1 | aksay.
# City log 402 of Set 1 | rocha.
# City log 403 of Set 1 | kahului.
# City log 404 of Set 1 | prainha.
# City log 405 of Set 1 | lanxi.
# City log 406 of Set 1 | bronnoysund.
# City log 407 of Set 1 | cefalu.
# City log 408 of Set 1 | akureyri.
# City log 409 of Set 1 | padang.
# City log 410 of Set 1 | paita.
# City log 411 of Set 1 | eydhafushi.
# City log 412 of Set 1 | siocon.
# City log 413 of Set 1 | zhigansk.
# City log 414 of Set 1 | houma.
# City log 415 of Set 1 | jaciara.
# City log 416 of Set 1 | gorin.
# City log 417 of Set 1 | deputatskiy.
# City log 418 of Set 1 | tongling.
# City log 419 of Set 1 | bandarbeyla.
# City log 420 of Set 1 | samarai.
# City log 421 of Set 1 | honningsvag.
# City log 422 of Set 1 | kalabo.
# City log 423 of Set 1 | assiniboia.
# City log 424 of Set 1 | nizhneyansk.
# City and associated data missing
# City log 425 of Set 1 | itarema.
# City log 426 of Set 1 | piedras negras.
# City log 427 of Set 1 | yeppoon.
# City log 428 of Set 1 | fuling.
# City log 429 of Set 1 | sibolga.
# City log 430 of Set 1 | samalaeulu.
# City and associated data missing
# City log 431 of Set 1 | harer.
# City log 432 of Set 1 | amapa.
# City log 433 of Set 1 | ofaqim.
# City log 434 of Set 1 | bauchi.
# City log 435 of Set 1 | nobeoka.
# City log 436 of Set 1 | deniliquin.
# City log 437 of Set 1 | bastia.
# City log 438 of Set 1 | tacuati.
# City log 439 of Set 1 | la ronge.
# City log 440 of Set 1 | payo.
# City log 441 of Set 1 | awjilah.
# City log 442 of Set 1 | dembi dolo.
# City log 443 of Set 1 | teofilo otoni.
# City log 444 of Set 1 | san rafael del sur.
# City log 445 of Set 1 | alghero.
# City log 446 of Set 1 | garmsar.
# City log 447 of Set 1 | urumqi.
# City log 448 of Set 1 | kaeo.
# City log 449 of Set 1 | bolitoc.
# City log 450 of Set 1 | oranjestad.
# City log 451 of Set 1 | mayari.
# City and associated data missing
# City log 452 of Set 1 | magadan.
# City log 453 of Set 1 | yuanping.
# City log 454 of Set 1 | fairbanks.
# City log 455 of Set 1 | camocim.
# City log 456 of Set 1 | dekar.
# City log 457 of Set 1 | asau.
# City log 458 of Set 1 | dunedin.
# City log 459 of Set 1 | kavaratti.
# City log 460 of Set 1 | arman.
# City log 461 of Set 1 | mount abu.
# City log 462 of Set 1 | palabuhanratu.
# City and associated data missing
# City log 463 of Set 1 | woodward.
# City log 464 of Set 1 | kawerau.
# City log 465 of Set 1 | macau.
# City log 466 of Set 1 | leshukonskoye.
# City log 467 of Set 1 | desaguadero.
# City log 468 of Set 1 | anadyr.
# City log 469 of Set 1 | bacolod.
# City log 470 of Set 1 | tawkar.
# City and associated data missing
# City log 471 of Set 1 | lewistown.
# City log 472 of Set 1 | holland.
# City log 473 of Set 1 | semey.
# City log 474 of Set 1 | belyy yar.
# City log 475 of Set 1 | douentza.
# City log 476 of Set 1 | san quintin.
# City log 477 of Set 1 | sal rei.
# City log 478 of Set 1 | savelugu.
# City log 479 of Set 1 | cortez.
# City log 480 of Set 1 | bolungarvik.
# City and associated data missing
# City log 481 of Set 1 | edd.
# City log 482 of Set 1 | churapcha.
# City log 483 of Set 1 | mairang.
# City log 484 of Set 1 | marcona.
# City and associated data missing
# City log 485 of Set 1 | ravar.
# City log 486 of Set 1 | ancud.
# City log 487 of Set 1 | freeport.
# City log 488 of Set 1 | filingue.
# City log 489 of Set 1 | roald.
# City log 490 of Set 1 | tarabha.
# City log 491 of Set 1 | palaikastron.
# City log 492 of Set 1 | mumford.
# City log 493 of Set 1 | leh.
# City log 494 of Set 1 | ballina.
# City and associated data missing
# City log 495 of Set 1 | cuenca.
# City log 496 of Set 1 | aasiaat.
# City log 497 of Set 1 | hualmay.
# City log 498 of Set 1 | grezzana.
# City log 499 of Set 1 | binika.
# City log 500 of Set 1 | dunlop.
# City log 501 of Set 1 | wucheng.
# City log 502 of Set 1 | khasan.
# City log 503 of Set 1 | taltal.
# City log 504 of Set 1 | ruatoria.
# City and associated data missing
# City log 505 of Set 1 | palmer.
# City log 506 of Set 1 | haukipudas.
# City log 507 of Set 1 | tarauaca.
# City log 508 of Set 1 | yakeshi.
# City log 509 of Set 1 | clones.
# City log 510 of Set 1 | gamba.
# City log 511 of Set 1 | puerto penasco.
# City log 512 of Set 1 | dolores.
# City log 513 of Set 1 | port blair.
# City log 514 of Set 1 | labytnangi.
# City log 515 of Set 1 | ilulissat.
# City log 516 of Set 1 | mkushi.
# City log 517 of Set 1 | mabaruma.
# City log 518 of Set 1 | misratah.
# City log 519 of Set 1 | hirara.
# City log 520 of Set 1 | mehamn.
# City log 521 of Set 1 | barranca.
# City log 522 of Set 1 | havre-saint-pierre.
# City log 523 of Set 1 | inuvik.
# City log 524 of Set 1 | qandala.
# City log 525 of Set 1 | boa vista.
# City log 526 of Set 1 | vershino-darasunskiy.
# City log 527 of Set 1 | sisimiut.
# City log 528 of Set 1 | port hedland.
# City log 529 of Set 1 | jabiru.
# City and associated data missing
# City log 530 of Set 1 | grand centre.
# City and associated data missing
# City log 531 of Set 1 | dwarka.
# City log 532 of Set 1 | bereda.
# City log 533 of Set 1 | ciucsangeorgiu.
# City log 534 of Set 1 | panguna.
# City log 535 of Set 1 | port hardy.
# City log 536 of Set 1 | richard toll.
# City and associated data missing
# City log 537 of Set 1 | lasa.
# City log 538 of Set 1 | traverse city.
# City log 539 of Set 1 | felidhoo.
# City and associated data missing
# City log 540 of Set 1 | patancheru.
# City log 541 of Set 1 | micheweni.
# City log 542 of Set 1 | san roque.
# City log 543 of Set 1 | komsomolskiy.
# City log 544 of Set 1 | ayan.
# City log 545 of Set 1 | teahupoo.
# City log 546 of Set 1 | katakwi.
# City log 547 of Set 1 | mafinga.
# City log 548 of Set 1 | santa clara.
# City log 549 of Set 1 | iskateley.
# City log 550 of Set 1 | clovis.
# City log 551 of Set 1 | rolim de moura.
# City and associated data missing
# City log 552 of Set 1 | les cayes.
# City log 553 of Set 1 | bintulu.
# City log 554 of Set 1 | marawi.
# City log 555 of Set 1 | gabu.
# City log 556 of Set 1 | omboue.
# City log 557 of Set 1 | parabel.
# City log 558 of Set 1 | imeni babushkina.
# City log 559 of Set 1 | venado tuerto.
# City log 560 of Set 1 | hurghada.
# City log 561 of Set 1 | north bend.
# City log 562 of Set 1 | tonantins.
# City log 563 of Set 1 | gemena.
# City log 564 of Set 1 | gao.
# City log 565 of Set 1 | chebsara.
# City log 566 of Set 1 | maumere.
# City log 567 of Set 1 | gravina in puglia.
# City log 568 of Set 1 | genhe.
# City log 569 of Set 1 | lensk.
# City log 570 of Set 1 | maceio.
# City log 571 of Set 1 | ust-nera.
# City log 572 of Set 1 | karasjok.
# City log 573 of Set 1 | palora.
# City log 574 of Set 1 | bulgan.
# City log 575 of Set 1 | iwanai.
# City log 576 of Set 1 | talara.
# City log 577 of Set 1 | texas city.
# City log 578 of Set 1 | soto la marina.
# City log 579 of Set 1 | vila franca do campo.
# City log 580 of Set 1 | coos bay.
# City log 581 of Set 1 | katangli.
# City log 582 of Set 1 | umzimvubu.
# City and associated data missing
# City log 583 of Set 1 | zhangye.
# City log 584 of Set 1 | paisley.
# City log 585 of Set 1 | takaka.
# City log 586 of Set 1 | linhares.
# City log 587 of Set 1 | arauco.
# City log 588 of Set 1 | borzya.
# City log 589 of Set 1 | ust-kuyga.
# City log 590 of Set 1 | biloela.
# City log 591 of Set 1 | puerto baquerizo moreno.
# City log 592 of Set 1 | soure.
# City log 593 of Set 1 | lufilufi.
# City log 594 of Set 1 | ossora.
# City log 595 of Set 1 | buala.
# City log 596 of Set 1 | malwan.
# City and associated data missing
# City log 597 of Set 1 | troitskoye.
# City log 598 of Set 1 | luganville.
# City log 599 of Set 1 | kalispell.
# City log 600 of Set 1 | ruwi.
# City log 601 of Set 1 | puno.
# City log 602 of Set 1 | jevargi.
# City log 603 of Set 1 | wajima.
# City log 604 of Set 1 | balabac.
# City log 605 of Set 1 | thunder bay.
# City log 606 of Set 1 | sinnar.
# City log 607 of Set 1 | labuan.
# City log 608 of Set 1 | bonthe.
# City log 609 of Set 1 | sorong.
# City log 610 of Set 1 | pokhara.
# City log 611 of Set 1 | mae hong son.
# City log 612 of Set 1 | christchurch.
# City log 613 of Set 1 | mudyuga.
# City and associated data missing

# %%
#show count of cities with weather data
cities_df.count()
# Out:
# City          613
# Lat           613
# Lng           613
# Max Temp      613
# Humidity      613
# Cloudiness    613
# Wind Speed    613
# Country       613
# Date          613
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#save to csv file
cities_df.to_csv("cities.csv")

#specify the URL and request results in Celsius and Fahrenheit
url = "http://api.openweathermap.org/data/2.5/weather?"
 
query_url = url + "appid" + weather_api_key + "&q=" + city


#Define temparature units for celsius and fahrenheit, metric and imperial respectively
celsius_url = url + "appid=" + weather_api_key + "&q=" + "&units=metric"
fahrenheit_url = url + "appid=" + weather_api_key + "&q=" + "&units=imperial"
max_temp = [(9/5)*(x - 273) + 32 for x in max_temp]



#Initialize data frame to store data from API calls                            
cities_df =pd.DataFrame({"City":city_list,
                         "Lat":lat,
                         "Lng":lng,
                         "Max Temp":max_temp,
                         "Humidity":humidity,
                         "Cloudiness":cloudiness,
                         "Wind Speed":wind_speed,
                         "Country":country,
                         "Date":date})
#round values in Max Temp col 
cities_df["Max Temp"].round(decimals=2)                           

#show cities Dataframe
cities_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Port-de-Bouc  43.40    4.98    50.270        93          20        2.10
# 1          Kajaani  64.23   27.73    26.870        92          90        1.00
# 2        Busselton -33.65  115.33    69.476        66         100        4.25
# 3        Coyhaique -45.58  -72.07    53.870        62           0        0.50
# 4     Constitución -35.33  -72.42    57.794        70           0        3.22
# 5  Severo-Kuril'sk  50.68  156.12    40.640        92         100       17.55
# 6         Hermanus -34.42   19.23    45.266        93           0        5.49
# 7  Bambous Virieux -20.34   57.76    69.278        54           0        3.13
# 8      Clyde River  70.47  -68.59    14.270        85          40        3.60
# 9             Hilo  19.73 -155.09    82.670        69          90        2.60
#
#   Country        Date
# 0      FR  1604112999
# 1      FI  1604112999
# 2      AU  1604112999
# 3      CL  1604113000
# 4      CL  1604113000
# 5      RU  1604113000
# 6      ZA  1604113000
# 7      MU  1604113000
# 8      CA  1604112946
# 9      US  1604113000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No City with a humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
#No City with a humidity > 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#No City with a humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature')
ax.scatter(cities_df['Lat'],cities_df['Max Temp'],edgecolors='red')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %% [markdown]
# Analysis for the plot above:
# The plot displays a latititude vs Max Temparature for selected cities.
# The closer a city is to the 0 degrees latititude (Equator), the higher the max temparature.
# Max temparature decreases as you drift further away from the equator and especially Northwards.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(cities_df['Lat'],cities_df['Humidity'],edgecolors='yellow')
plt.grid()
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# Analysis for the plot above:
# The plot displays a latititude vs humidity for selected cities.
# Cities below the equator have a higher average humidity percentage compared to the cities north of the equator which have a  generally well distributed average percentage.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(cities_df['Lat'],cities_df['Cloudiness'],edgecolors='blue')
plt.grid()
fig.savefig('lat_vs_cloudiness.png')

# %% [markdown]
# Analysis for the plot above:
# The plot displays a latititude vs Cloudiness for selected cities.
# There is no significant difference in the cloudiness based on latitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(cities_df['Lat'],cities_df['Wind Speed'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_wind_speed.png')

# %% [markdown]
# Analysis for the plot above:
# The plot displays a latititude vs humidity for selected cities.
# The wind speed is at a low average 4-5 mph close to the equator both sides. However the speed increases slightly as you drift away fron the equator both sides.

# %% [markdown]
# ## Linear Regression

# %%
#Create Northern and Southern Hemisphere DataFrames

#Northern Hemisphere (Lat > 0)
cities_df_north = cities_df[cities_df['Lat'] >= 0]

#Southern Hemisphere (Lat < 0)
cities_df_south = cities_df[cities_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_north['Lat']
y_values = cities_df_north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Max Temperature vs. City Latitude (North)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Max Temperature (F)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: -0.8846492506611984

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_south['Lat']
y_values = cities_df_south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Max Temperature vs. City Latitude (south)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Max Temperature (F)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.5899736645925827

# %% [markdown]
# Analysis for the 2 plots above:
# The 2 plots displays latitude in relationship with Max temparatures accross both Northern and southern hemispheres.
# 1.The linear regression lines indicate steeper drop in temparature as you drift further north from the equator.
# 2.Its clear that as you move away from the equator towards both sides of the hemisphere, there is a significant drop in     temparature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_north['Lat']
y_values = cities_df_north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Humidity vs. City Latitude (north)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Humidity (%)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.3528374273296414

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_south['Lat']
y_values = cities_df_south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Humidity vs. City Latitude (south)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Humidity (%)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.10215761303921699

# %% [markdown]
# Analysis for the 2 plots above:
# The 2 plots displays latitude in relationship with Humidity accross both Northern and Southern hemispheres.
# 1.Both hemispheres show very slight changes in Humidity as you move away from the equator.
# 2.The humidity has a low but constant increase Northwards and a low but constant decrease Southwards.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_north['Lat']
y_values = cities_df_north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Cloudiness vs. City Latitude (north)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Cloudiness (%)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.2259072931438753

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_south['Lat']
y_values = cities_df_south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Cloudiness vs. City Latitude (south)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Cloudiness (%)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.2157775028222767

# %% [markdown]
# Analysis for the 2 plots above:
# The 2 plots displays latitude in relationship with Cloudiness accross both Northern and Southern hemispheres.
# 1.Overall there is very little impact of latititude towards cloudiness.
# 2.However,the Northern hemispere shows a more cloudy situation in this analysis

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_north['Lat']
y_values = cities_df_north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(0,30),fontsize=15,color='red')
plt.grid()
plt.title('Wind Speed vs. City Latitude (north)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Wind Speed (mph)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: 0.16193875573379823

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#setup linear regression and line equation
x_values = cities_df_south['Lat']
y_values = cities_df_south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


#generate plot
lat_temp_reg_n = plt.scatter(x_values,y_values,marker='o',edgecolors='black')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, xy=(-50,20),fontsize=15,color='red')
plt.grid()
plt.title('Wind Speed vs. City Latitude (South)',size=18)
plt.xlabel('Latitude',size=15)
plt.ylabel('Wind Speed (mph)',size=15)
plt.show()

#r2
print(f'The r squared is: {rvalue}')
# Out:
# The r squared is: -0.23604455098747582

# %% [markdown]
# Analysis for the 2 plots above:
# The 2 plots displays latitude in relationship with Wind Speed accross both Northern and Southern hemispheres.
# 1.The average windspeed in the Northern Hemisphere is consistent at about 3-4mph. The Linear regression line shows a very slight rising slope.
# 2.On the other hand, the Southern hemisphere has an increased windspeed as shown by the linear regression line with very scattered higher speeds spread out.
