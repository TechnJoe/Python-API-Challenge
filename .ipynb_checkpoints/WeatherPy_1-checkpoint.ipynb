# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\man-y\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\man-y\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import csv
import numpy as np
import requests
import time
from pandas import DataFrame
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# create the dataframe to hold city info
cities_df = pd.DataFrame({"City":cities})
cities_df['Lat'] = ''
cities_df['Lng'] = ''
cities_df['Max Temp'] = ''
cities_df['Humidity'] = ''
cities_df['Cloudiness'] = ''
cities_df['Wind Speed'] = ''
cities_df['Country'] = ''
cities_df['Date'] = ''

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 1

# create the lists to hold the data for each city
city_list = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []




for city in cities:    
        # setup url and make API request
        print(f"City log {count} of Set 1 | {city}.")
        count = count + 1
        
        target_url = ("http://api.openweathermap.org/data/2.5/weather?"
                      'appid={0}&q={1}').format(weather_api_key,city)
        try:
            # extract results
            response = requests.get(target_url).json()
            
            # add the city info to the lists             
            city_list.append(response['name'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            humidity.append(response['main']['humidity'])
            cloudiness.append(response['clouds']['all'])
            wind_speed.append(response['wind']['speed'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
           
           
           
            
        except:
            print("skip missing City and data")
# Out:
# City log 1 of Set 1 | bethel.
# City log 2 of Set 1 | sentyabrskiy.
# skip missing City and data
# City log 3 of Set 1 | nizhneyansk.
# skip missing City and data
# City log 4 of Set 1 | matrei.
# skip missing City and data
# City log 5 of Set 1 | darhan.
# City log 6 of Set 1 | anshun.
# City log 7 of Set 1 | rocha.
# City log 8 of Set 1 | luganville.
# City log 9 of Set 1 | berezovyy.
# City log 10 of Set 1 | busselton.
# City log 11 of Set 1 | orgtrud.
# City log 12 of Set 1 | upernavik.
# City log 13 of Set 1 | pergamino.
# City log 14 of Set 1 | east london.
# City log 15 of Set 1 | krasnoarmeysk.
# City log 16 of Set 1 | lasa.
# City log 17 of Set 1 | mahebourg.
# City log 18 of Set 1 | olavarria.
# City log 19 of Set 1 | ketchikan.
# City log 20 of Set 1 | kaitangata.
# City log 21 of Set 1 | mugur-aksy.
# City log 22 of Set 1 | ushuaia.
# City log 23 of Set 1 | kurumkan.
# City log 24 of Set 1 | tunxi.
# skip missing City and data
# City log 25 of Set 1 | hilo.
# City log 26 of Set 1 | hermanus.
# City log 27 of Set 1 | kapaa.
# City log 28 of Set 1 | bredasdorp.
# City log 29 of Set 1 | rikitea.
# City log 30 of Set 1 | rincon.
# City log 31 of Set 1 | sola.
# City log 32 of Set 1 | mataura.
# City log 33 of Set 1 | provideniya.
# City log 34 of Set 1 | verkh-suetka.
# City log 35 of Set 1 | dingle.
# City log 36 of Set 1 | tiksi.
# City log 37 of Set 1 | atuona.
# City log 38 of Set 1 | tasiilaq.
# City log 39 of Set 1 | yefira.
# skip missing City and data
# City log 40 of Set 1 | butaritari.
# City log 41 of Set 1 | mys shmidta.
# skip missing City and data
# City log 42 of Set 1 | najran.
# City log 43 of Set 1 | lata.
# City log 44 of Set 1 | noyabrsk.
# City log 45 of Set 1 | port alfred.
# City log 46 of Set 1 | broken hill.
# City log 47 of Set 1 | albany.
# City log 48 of Set 1 | ostrogozhsk.
# City log 49 of Set 1 | pacific grove.
# City log 50 of Set 1 | karpathos.
# City log 51 of Set 1 | cockburn town.
# City log 52 of Set 1 | castro.
# City log 53 of Set 1 | tombouctou.
# City log 54 of Set 1 | khatanga.
# City log 55 of Set 1 | flinders.
# City log 56 of Set 1 | andros town.
# City log 57 of Set 1 | vallenar.
# City log 58 of Set 1 | socorro.
# City log 59 of Set 1 | huarmey.
# City log 60 of Set 1 | daru.
# City log 61 of Set 1 | saleaula.
# skip missing City and data
# City log 62 of Set 1 | saint-georges.
# City log 63 of Set 1 | lesnyye polyany.
# City log 64 of Set 1 | dikson.
# City log 65 of Set 1 | tahe.
# City log 66 of Set 1 | luanda.
# City log 67 of Set 1 | gamba.
# City log 68 of Set 1 | torbay.
# City log 69 of Set 1 | taolanaro.
# skip missing City and data
# City log 70 of Set 1 | pevek.
# City log 71 of Set 1 | pozo colorado.
# City log 72 of Set 1 | nelson bay.
# City log 73 of Set 1 | saldanha.
# City log 74 of Set 1 | valenza.
# City log 75 of Set 1 | alekseyevka.
# City log 76 of Set 1 | hamilton.
# City log 77 of Set 1 | louisbourg.
# skip missing City and data
# City log 78 of Set 1 | nikolskoye.
# City log 79 of Set 1 | hobyo.
# City log 80 of Set 1 | belushya guba.
# skip missing City and data
# City log 81 of Set 1 | bluff.
# City log 82 of Set 1 | tornio.
# City log 83 of Set 1 | port elizabeth.
# City log 84 of Set 1 | cape town.
# City log 85 of Set 1 | port macquarie.
# City log 86 of Set 1 | bull savanna.
# City log 87 of Set 1 | cabo san lucas.
# City log 88 of Set 1 | kahului.
# City log 89 of Set 1 | sorland.
# City log 90 of Set 1 | luderitz.
# City log 91 of Set 1 | punta arenas.
# City log 92 of Set 1 | presque isle.
# City log 93 of Set 1 | thompson.
# City log 94 of Set 1 | lorengau.
# City log 95 of Set 1 | ostrovnoy.
# City log 96 of Set 1 | pundaguitan.
# City log 97 of Set 1 | hobart.
# City log 98 of Set 1 | megion.
# City log 99 of Set 1 | katsuura.
# City log 100 of Set 1 | haimen.
# City log 101 of Set 1 | tuktoyaktuk.
# City log 102 of Set 1 | akyab.
# City log 103 of Set 1 | georgetown.
# City log 104 of Set 1 | guerrero negro.
# City log 105 of Set 1 | vardo.
# City log 106 of Set 1 | havelock.
# City log 107 of Set 1 | rio branco.
# City log 108 of Set 1 | predivinsk.
# City log 109 of Set 1 | zhangye.
# City log 110 of Set 1 | lantawan.
# City log 111 of Set 1 | praya.
# City log 112 of Set 1 | narsaq.
# City log 113 of Set 1 | biak.
# City log 114 of Set 1 | asau.
# City log 115 of Set 1 | batagay-alyta.
# City log 116 of Set 1 | grenada.
# City log 117 of Set 1 | ugoofaaru.
# City log 118 of Set 1 | jiaojiang.
# City log 119 of Set 1 | avarua.
# City log 120 of Set 1 | mar del plata.
# City log 121 of Set 1 | mogadishu.
# City log 122 of Set 1 | namtsy.
# City log 123 of Set 1 | fremont.
# City log 124 of Set 1 | lebu.
# City log 125 of Set 1 | ovsyanka.
# City log 126 of Set 1 | masinigudi.
# City log 127 of Set 1 | qaanaaq.
# City log 128 of Set 1 | new norfolk.
# City log 129 of Set 1 | kununurra.
# City log 130 of Set 1 | peterhead.
# City log 131 of Set 1 | sevierville.
# City log 132 of Set 1 | kavieng.
# City log 133 of Set 1 | naze.
# City log 134 of Set 1 | carnarvon.
# City log 135 of Set 1 | stillwater.
# City log 136 of Set 1 | pitimbu.
# City log 137 of Set 1 | makinsk.
# City log 138 of Set 1 | bengkulu.
# City log 139 of Set 1 | palu.
# City log 140 of Set 1 | deputatskiy.
# City log 141 of Set 1 | nome.
# City log 142 of Set 1 | halifax.
# City log 143 of Set 1 | puerto ayora.
# City log 144 of Set 1 | peace river.
# City log 145 of Set 1 | bargal.
# skip missing City and data
# City log 146 of Set 1 | atbasar.
# City log 147 of Set 1 | vaitupu.
# skip missing City and data
# City log 148 of Set 1 | ribeira grande.
# City log 149 of Set 1 | kalomo.
# skip missing City and data
# City log 150 of Set 1 | vila velha.
# City log 151 of Set 1 | jeremie.
# City log 152 of Set 1 | tonj.
# City log 153 of Set 1 | fene.
# City log 154 of Set 1 | evensk.
# City log 155 of Set 1 | yellowknife.
# City log 156 of Set 1 | victoria.
# City log 157 of Set 1 | greenville.
# City log 158 of Set 1 | cayenne.
# City log 159 of Set 1 | saint anthony.
# City log 160 of Set 1 | zhigansk.
# City log 161 of Set 1 | hailar.
# City log 162 of Set 1 | tsihombe.
# skip missing City and data
# City log 163 of Set 1 | kashi.
# City log 164 of Set 1 | ponta do sol.
# City log 165 of Set 1 | vung tau.
# City log 166 of Set 1 | port arthur.
# City log 167 of Set 1 | palabuhanratu.
# skip missing City and data
# City log 168 of Set 1 | vaini.
# City log 169 of Set 1 | katangli.
# City log 170 of Set 1 | horta.
# City log 171 of Set 1 | amarwara.
# City log 172 of Set 1 | chuy.
# City log 173 of Set 1 | jamestown.
# City log 174 of Set 1 | maceio.
# City log 175 of Set 1 | hirara.
# City log 176 of Set 1 | sao jose da coroa grande.
# City log 177 of Set 1 | esperance.
# City log 178 of Set 1 | sibolga.
# City log 179 of Set 1 | kodiak.
# City log 180 of Set 1 | pionki.
# City log 181 of Set 1 | labrea.
# City log 182 of Set 1 | kruisfontein.
# City log 183 of Set 1 | shimoda.
# City log 184 of Set 1 | klaksvik.
# City log 185 of Set 1 | iqaluit.
# City log 186 of Set 1 | barentsburg.
# skip missing City and data
# City log 187 of Set 1 | praia.
# City log 188 of Set 1 | martinsville.
# City log 189 of Set 1 | salalah.
# City log 190 of Set 1 | ballangen.
# City log 191 of Set 1 | weyburn.
# City log 192 of Set 1 | shieli.
# City log 193 of Set 1 | port hardy.
# City log 194 of Set 1 | kurilsk.
# City log 195 of Set 1 | greencastle.
# City log 196 of Set 1 | cuamba.
# City log 197 of Set 1 | berlevag.
# City log 198 of Set 1 | vila franca do campo.
# City log 199 of Set 1 | attawapiskat.
# skip missing City and data
# City log 200 of Set 1 | simao.
# City log 201 of Set 1 | bilibino.
# City log 202 of Set 1 | lolua.
# skip missing City and data
# City log 203 of Set 1 | santa maria.
# City log 204 of Set 1 | san cristobal.
# City log 205 of Set 1 | tabou.
# City log 206 of Set 1 | nanortalik.
# City log 207 of Set 1 | illoqqortoormiut.
# skip missing City and data
# City log 208 of Set 1 | tuatapere.
# City log 209 of Set 1 | olafsvik.
# City log 210 of Set 1 | sistranda.
# City log 211 of Set 1 | puerto madero.
# City log 212 of Set 1 | barrow.
# City log 213 of Set 1 | miraflores.
# City log 214 of Set 1 | caravelas.
# City log 215 of Set 1 | corinto.
# City log 216 of Set 1 | tsiroanomandidy.
# City log 217 of Set 1 | omboue.
# City log 218 of Set 1 | hidrolandia.
# City log 219 of Set 1 | easton.
# City log 220 of Set 1 | arraial do cabo.
# City log 221 of Set 1 | dicabisagan.
# City log 222 of Set 1 | te anau.
# City log 223 of Set 1 | rio grande.
# City log 224 of Set 1 | mandalgovi.
# City log 225 of Set 1 | vitim.
# City log 226 of Set 1 | kavaratti.
# City log 227 of Set 1 | codrington.
# City log 228 of Set 1 | satipo.
# City log 229 of Set 1 | luwuk.
# City log 230 of Set 1 | souillac.
# City log 231 of Set 1 | bacuit.
# skip missing City and data
# City log 232 of Set 1 | marsh harbour.
# City log 233 of Set 1 | hofn.
# City log 234 of Set 1 | buin.
# City log 235 of Set 1 | benghazi.
# City log 236 of Set 1 | sitka.
# City log 237 of Set 1 | poum.
# City log 238 of Set 1 | abeche.
# City log 239 of Set 1 | fairbanks.
# City log 240 of Set 1 | dunmore town.
# City log 241 of Set 1 | salmo.
# City log 242 of Set 1 | amderma.
# skip missing City and data
# City log 243 of Set 1 | longyearbyen.
# City log 244 of Set 1 | fort nelson.
# City log 245 of Set 1 | montague.
# City log 246 of Set 1 | hammerfest.
# City log 247 of Set 1 | krasnoye.
# City log 248 of Set 1 | balabac.
# City log 249 of Set 1 | alofi.
# City log 250 of Set 1 | riberalta.
# City log 251 of Set 1 | abu zabad.
# City log 252 of Set 1 | hithadhoo.
# City log 253 of Set 1 | tommot.
# City log 254 of Set 1 | almaznyy.
# City log 255 of Set 1 | gigmoto.
# City log 256 of Set 1 | tehachapi.
# City log 257 of Set 1 | harper.
# City log 258 of Set 1 | port lincoln.
# City log 259 of Set 1 | bundaberg.
# City log 260 of Set 1 | george town.
# City log 261 of Set 1 | ust-nera.
# City log 262 of Set 1 | siteki.
# City log 263 of Set 1 | itaituba.
# City log 264 of Set 1 | colac.
# City log 265 of Set 1 | velikie luki.
# skip missing City and data
# City log 266 of Set 1 | hami.
# City log 267 of Set 1 | meyungs.
# skip missing City and data
# City log 268 of Set 1 | pisco.
# City log 269 of Set 1 | santa luzia.
# City log 270 of Set 1 | buenos aires.
# City log 271 of Set 1 | zhaoqing.
# City log 272 of Set 1 | havre.
# City log 273 of Set 1 | tlapacoyan.
# City log 274 of Set 1 | dong xoai.
# City log 275 of Set 1 | norman wells.
# City log 276 of Set 1 | lewistown.
# City log 277 of Set 1 | komsomolskiy.
# City log 278 of Set 1 | mbanza-ngungu.
# City log 279 of Set 1 | bandarbeyla.
# City log 280 of Set 1 | pareora.
# City log 281 of Set 1 | masunga.
# City log 282 of Set 1 | aksarka.
# City log 283 of Set 1 | selma.
# City log 284 of Set 1 | kamenskoye.
# skip missing City and data
# City log 285 of Set 1 | kathmandu.
# City log 286 of Set 1 | aasiaat.
# City log 287 of Set 1 | bur gabo.
# skip missing City and data
# City log 288 of Set 1 | port said.
# City log 289 of Set 1 | saint-louis.
# City log 290 of Set 1 | molepolole.
# City log 291 of Set 1 | tiznit.
# City log 292 of Set 1 | aklavik.
# City log 293 of Set 1 | sorvag.
# skip missing City and data
# City log 294 of Set 1 | nanlong.
# City log 295 of Set 1 | bayevo.
# City log 296 of Set 1 | airai.
# City log 297 of Set 1 | mayna.
# City log 298 of Set 1 | cidreira.
# City log 299 of Set 1 | severo-kurilsk.
# City log 300 of Set 1 | chokurdakh.
# City log 301 of Set 1 | manicore.
# City log 302 of Set 1 | angren.
# City log 303 of Set 1 | curup.
# City log 304 of Set 1 | constitucion.
# City log 305 of Set 1 | yatou.
# City log 306 of Set 1 | port keats.
# City log 307 of Set 1 | sao filipe.
# City log 308 of Set 1 | severnyy.
# City log 309 of Set 1 | rawson.
# City log 310 of Set 1 | buchanan.
# City log 311 of Set 1 | houlton.
# City log 312 of Set 1 | fethiye.
# City log 313 of Set 1 | saskylakh.
# City log 314 of Set 1 | mayo.
# City log 315 of Set 1 | kungurtug.
# City log 316 of Set 1 | bodden town.
# City log 317 of Set 1 | san jose.
# City log 318 of Set 1 | shakiso.
# City log 319 of Set 1 | kirishi.
# City log 320 of Set 1 | paamiut.
# City log 321 of Set 1 | batemans bay.
# City log 322 of Set 1 | pierre.
# City log 323 of Set 1 | ancud.
# City log 324 of Set 1 | samarai.
# City log 325 of Set 1 | yumen.
# City log 326 of Set 1 | watford.
# City log 327 of Set 1 | srednekolymsk.
# City log 328 of Set 1 | hermiston.
# City log 329 of Set 1 | hovd.
# City log 330 of Set 1 | aguimes.
# City log 331 of Set 1 | coihaique.
# City log 332 of Set 1 | umzimvubu.
# skip missing City and data
# City log 333 of Set 1 | eyl.
# City log 334 of Set 1 | kawana waters.
# skip missing City and data
# City log 335 of Set 1 | kosh-agach.
# City log 336 of Set 1 | aflu.
# skip missing City and data
# City log 337 of Set 1 | arlit.
# City log 338 of Set 1 | mount gambier.
# City log 339 of Set 1 | mecca.
# City log 340 of Set 1 | satitoa.
# skip missing City and data
# City log 341 of Set 1 | lima.
# City log 342 of Set 1 | suhbaatar.
# City log 343 of Set 1 | bud.
# City log 344 of Set 1 | amalapuram.
# City log 345 of Set 1 | yeniseysk.
# City log 346 of Set 1 | broome.
# City log 347 of Set 1 | vanavara.
# City log 348 of Set 1 | tacoronte.
# City log 349 of Set 1 | hambantota.
# City log 350 of Set 1 | haines junction.
# City log 351 of Set 1 | grand gaube.
# City log 352 of Set 1 | hays.
# City log 353 of Set 1 | rudnyy.
# City log 354 of Set 1 | radomsko.
# City log 355 of Set 1 | acarau.
# City log 356 of Set 1 | cherskiy.
# City log 357 of Set 1 | santa isabel.
# City log 358 of Set 1 | eskasem.
# skip missing City and data
# City log 359 of Set 1 | marcona.
# skip missing City and data
# City log 360 of Set 1 | laguna.
# City log 361 of Set 1 | saint-philippe.
# City log 362 of Set 1 | krasnokamensk.
# City log 363 of Set 1 | abha.
# City log 364 of Set 1 | itarema.
# City log 365 of Set 1 | maniitsoq.
# City log 366 of Set 1 | vao.
# City log 367 of Set 1 | babanusah.
# skip missing City and data
# City log 368 of Set 1 | auxerre.
# City log 369 of Set 1 | miramar.
# City log 370 of Set 1 | poceirao.
# City log 371 of Set 1 | port hedland.
# City log 372 of Set 1 | geraldton.
# City log 373 of Set 1 | pemangkat.
# City log 374 of Set 1 | qaqortoq.
# City log 375 of Set 1 | mansa.
# City log 376 of Set 1 | dawson creek.
# City log 377 of Set 1 | colares.
# City log 378 of Set 1 | tecoanapa.
# City log 379 of Set 1 | tautira.
# City log 380 of Set 1 | port blair.
# City log 381 of Set 1 | kashmor.
# City log 382 of Set 1 | dori.
# City log 383 of Set 1 | wanning.
# City log 384 of Set 1 | borama.
# skip missing City and data
# City log 385 of Set 1 | darnah.
# City log 386 of Set 1 | santa marta.
# City log 387 of Set 1 | parfenyevo.
# City log 388 of Set 1 | teya.
# City log 389 of Set 1 | half moon bay.
# City log 390 of Set 1 | necochea.
# City log 391 of Set 1 | ucluelet.
# City log 392 of Set 1 | samusu.
# skip missing City and data
# City log 393 of Set 1 | taoudenni.
# City log 394 of Set 1 | arona.
# City log 395 of Set 1 | voh.
# City log 396 of Set 1 | porirua.
# City log 397 of Set 1 | beringovskiy.
# City log 398 of Set 1 | longkou.
# City log 399 of Set 1 | gushikawa.
# City log 400 of Set 1 | riwaka.
# City log 401 of Set 1 | ventersburg.
# City log 402 of Set 1 | zhezkazgan.
# City log 403 of Set 1 | tilichiki.
# City log 404 of Set 1 | burgstadt.
# City log 405 of Set 1 | talant.
# City log 406 of Set 1 | lompoc.
# City log 407 of Set 1 | jibuti.
# City log 408 of Set 1 | polyarnyy.
# City log 409 of Set 1 | coahuayana.
# City log 410 of Set 1 | comodoro rivadavia.
# City log 411 of Set 1 | san jose acatempa.
# City log 412 of Set 1 | galiwinku.
# skip missing City and data
# City log 413 of Set 1 | atambua.
# City log 414 of Set 1 | orumiyeh.
# City log 415 of Set 1 | sorso.
# City log 416 of Set 1 | paucartambo.
# skip missing City and data
# City log 417 of Set 1 | attur.
# City log 418 of Set 1 | parla.
# City log 419 of Set 1 | genhe.
# City log 420 of Set 1 | angouleme.
# City log 421 of Set 1 | bathsheba.
# City log 422 of Set 1 | santiago.
# City log 423 of Set 1 | makakilo city.
# City log 424 of Set 1 | chernyshevskiy.
# City log 425 of Set 1 | ahumada.
# skip missing City and data
# City log 426 of Set 1 | benalla.
# City log 427 of Set 1 | togur.
# City log 428 of Set 1 | santa vitoria do palmar.
# City log 429 of Set 1 | ust-kuyga.
# City log 430 of Set 1 | cap malheureux.
# City log 431 of Set 1 | bintulu.
# City log 432 of Set 1 | gerede.
# City log 433 of Set 1 | namibe.
# City log 434 of Set 1 | bajil.
# City log 435 of Set 1 | ugep.
# City log 436 of Set 1 | mlonggo.
# City log 437 of Set 1 | itoman.
# City log 438 of Set 1 | bihoro.
# City log 439 of Set 1 | sur.
# City log 440 of Set 1 | sao lourenco do sul.
# City log 441 of Set 1 | burica.
# skip missing City and data
# City log 442 of Set 1 | krasnogorsk.
# City log 443 of Set 1 | cabedelo.
# City log 444 of Set 1 | bow island.
# City log 445 of Set 1 | la ronge.
# City log 446 of Set 1 | ruatoria.
# skip missing City and data
# City log 447 of Set 1 | kodinsk.
# City log 448 of Set 1 | solnechnyy.
# City log 449 of Set 1 | sobolevo.
# City log 450 of Set 1 | grand river south east.
# skip missing City and data
# City log 451 of Set 1 | korla.
# City log 452 of Set 1 | hasaki.
# City log 453 of Set 1 | teguise.
# City log 454 of Set 1 | hanmer springs.
# City log 455 of Set 1 | verkhoyansk.
# City log 456 of Set 1 | yamada.
# City log 457 of Set 1 | coolum beach.
# City log 458 of Set 1 | otane.
# City log 459 of Set 1 | puerto escondido.
# City log 460 of Set 1 | gat.
# City log 461 of Set 1 | temaraia.
# skip missing City and data
# City log 462 of Set 1 | san quintin.
# City log 463 of Set 1 | san patricio.
# City log 464 of Set 1 | northam.
# City log 465 of Set 1 | linguere.
# City log 466 of Set 1 | dakar.
# City log 467 of Set 1 | malwan.
# skip missing City and data
# City log 468 of Set 1 | tarnobrzeg.
# City log 469 of Set 1 | conakry.
# City log 470 of Set 1 | popova.
# City log 471 of Set 1 | antalaha.
# City log 472 of Set 1 | kirakira.
# City log 473 of Set 1 | ontario.
# City log 474 of Set 1 | xichang.
# City log 475 of Set 1 | praia da vitoria.
# City log 476 of Set 1 | mercedes.
# City log 477 of Set 1 | tabuk.
# City log 478 of Set 1 | joshimath.
# City log 479 of Set 1 | talnakh.
# City log 480 of Set 1 | paka.
# City log 481 of Set 1 | arroyo.
# City log 482 of Set 1 | iberia.
# City log 483 of Set 1 | kedrovyy.
# City log 484 of Set 1 | faanui.
# City log 485 of Set 1 | marystown.
# City log 486 of Set 1 | hornepayne.
# City log 487 of Set 1 | karratha.
# City log 488 of Set 1 | karpogory.
# City log 489 of Set 1 | aranos.
# City log 490 of Set 1 | touros.
# City log 491 of Set 1 | remanso.
# City log 492 of Set 1 | norfolk.
# City log 493 of Set 1 | ilulissat.
# City log 494 of Set 1 | findlay.
# City log 495 of Set 1 | tumbes.
# City log 496 of Set 1 | calama.
# City log 497 of Set 1 | buala.
# City log 498 of Set 1 | nemuro.
# City log 499 of Set 1 | shubarshi.
# City log 500 of Set 1 | port moresby.
# City log 501 of Set 1 | mwinilunga.
# City log 502 of Set 1 | gargunnock.
# City log 503 of Set 1 | padang.
# City log 504 of Set 1 | yichang.
# City log 505 of Set 1 | quelimane.
# City log 506 of Set 1 | yulara.
# City log 507 of Set 1 | dunbar.
# City log 508 of Set 1 | changji.
# City log 509 of Set 1 | fortuna.
# City log 510 of Set 1 | matay.
# City log 511 of Set 1 | port shepstone.
# City log 512 of Set 1 | banjar.
# City log 513 of Set 1 | kloulklubed.
# City log 514 of Set 1 | barmer.
# City log 515 of Set 1 | ahipara.
# City log 516 of Set 1 | energeticheskiy.
# City log 517 of Set 1 | sovetskiy.
# City log 518 of Set 1 | arcos de la frontera.
# City log 519 of Set 1 | tabiauea.
# skip missing City and data
# City log 520 of Set 1 | alice springs.
# City log 521 of Set 1 | bahia blanca.
# City log 522 of Set 1 | karaj.
# City log 523 of Set 1 | kyshtovka.
# City log 524 of Set 1 | erenhot.
# City log 525 of Set 1 | lavrentiya.
# City log 526 of Set 1 | tandalti.
# City log 527 of Set 1 | urengoy.
# City log 528 of Set 1 | college station.
# City log 529 of Set 1 | berdychiv.
# City log 530 of Set 1 | namatanai.
# City log 531 of Set 1 | kuytun.
# City log 532 of Set 1 | siavonga.
# City log 533 of Set 1 | labutta.
# skip missing City and data
# City log 534 of Set 1 | tel aviv-yafo.
# City log 535 of Set 1 | bad neustadt.
# skip missing City and data
# City log 536 of Set 1 | yeehaw junction.
# skip missing City and data
# City log 537 of Set 1 | guaymas.
# City log 538 of Set 1 | uhingen.
# City log 539 of Set 1 | archidona.
# City log 540 of Set 1 | amazar.
# City log 541 of Set 1 | kazalinsk.
# skip missing City and data
# City log 542 of Set 1 | linchuan.
# skip missing City and data
# City log 543 of Set 1 | beloha.
# City log 544 of Set 1 | naldurg.
# City log 545 of Set 1 | dolbeau.
# skip missing City and data
# City log 546 of Set 1 | macusani.
# City log 547 of Set 1 | aquiraz.
# City log 548 of Set 1 | derbent.
# City log 549 of Set 1 | seoul.
# City log 550 of Set 1 | pandamatenga.
# City log 551 of Set 1 | henties bay.
# City log 552 of Set 1 | mosquera.
# City log 553 of Set 1 | ojinaga.
# City log 554 of Set 1 | petatlan.
# City log 555 of Set 1 | mujiayingzi.
# City log 556 of Set 1 | porto tolle.
# City log 557 of Set 1 | barranca.
# City log 558 of Set 1 | akot.
# City log 559 of Set 1 | lagoa.
# City log 560 of Set 1 | leh.
# City log 561 of Set 1 | khovu-aksy.
# City log 562 of Set 1 | dhadar.
# City log 563 of Set 1 | sao pedro da aldeia.
# City log 564 of Set 1 | tahta.
# City log 565 of Set 1 | talara.
# City log 566 of Set 1 | khandagayty.
# City log 567 of Set 1 | gold coast.
# City log 568 of Set 1 | svetlogorsk.
# City log 569 of Set 1 | barra da estiva.
# City log 570 of Set 1 | porto velho.
# City log 571 of Set 1 | llanes.
# City log 572 of Set 1 | neftcala.
# City log 573 of Set 1 | dzhusaly.
# skip missing City and data
# City log 574 of Set 1 | nsanje.
# City log 575 of Set 1 | bagnara calabra.
# City log 576 of Set 1 | gannan.
# City log 577 of Set 1 | bokoro.
# City log 578 of Set 1 | kieta.
# City log 579 of Set 1 | never.
# City log 580 of Set 1 | bulawayo.
# City log 581 of Set 1 | beyneu.
# City log 582 of Set 1 | brae.
# City log 583 of Set 1 | portland.
# City log 584 of Set 1 | ouesso.
# City log 585 of Set 1 | talaya.
# City log 586 of Set 1 | bocanda.
# City log 587 of Set 1 | tutoia.
# City log 588 of Set 1 | adrar.
# City log 589 of Set 1 | bilma.
# City log 590 of Set 1 | rungata.
# skip missing City and data
# City log 591 of Set 1 | grand-lahou.
# City log 592 of Set 1 | warqla.
# skip missing City and data
# City log 593 of Set 1 | sao joao da barra.
# City log 594 of Set 1 | beidao.
# City log 595 of Set 1 | manali.
# City log 596 of Set 1 | kapuskasing.
# City log 597 of Set 1 | letlhakane.
# City log 598 of Set 1 | soller.
# City log 599 of Set 1 | zachagansk.
# skip missing City and data
# City log 600 of Set 1 | richards bay.
# City log 601 of Set 1 | saint george.
# City log 602 of Set 1 | kuala terengganu.
# City log 603 of Set 1 | matagami.
# City log 604 of Set 1 | cagayan de tawi-tawi.
# skip missing City and data
# City log 605 of Set 1 | dudinka.
# City log 606 of Set 1 | margate.
# City log 607 of Set 1 | mayumba.
# City log 608 of Set 1 | pangnirtung.
# City log 609 of Set 1 | saryshagan.
# skip missing City and data
# City log 610 of Set 1 | paducah.
# City log 611 of Set 1 | valparaiso.
# City log 612 of Set 1 | quang ngai.
# City log 613 of Set 1 | santa fe.
# City log 614 of Set 1 | shepsi.
# City log 615 of Set 1 | balkanabat.
# City log 616 of Set 1 | mahina.
# City log 617 of Set 1 | muhos.
# City log 618 of Set 1 | jining.
# City log 619 of Set 1 | roebourne.
# City log 620 of Set 1 | challapata.
# City log 621 of Set 1 | fomboni.
# City log 622 of Set 1 | nouakchott.
# City log 623 of Set 1 | sumenep.
# City log 624 of Set 1 | quatre cocos.

# %%
#show count of cities with weather data
cities_df.count()
# Out:
# City          624
# Lat           624
# Lng           624
# Max Temp      624
# Humidity      624
# Cloudiness    624
# Wind Speed    624
# Country       624
# Date          624
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#save to csv file
cities_df.to_csv("cities.csv")

#specify the URL and request results in Celsius and Fahrenheit
url = "http://api.openweathermap.org/data/2.5/weather?"
 
query_url = url + "appid" + weather_api_key + "&q=" + city


#Define temparature units for celsius and fahrenheit, metric and imperial respectively
celsius_url = url + "appid=" + weather_api_key + "&q=" + "&units=metric"
fahrenheit_url = url + "appid=" + weather_api_key + "&q=" + "&units=imperial"
max_temp = [(9/5)*(x - 273) + 32 for x in max_temp]



#Initialize data frame to store data from API calls                            
cities_df =pd.DataFrame({"City":city_list,
                         "Lat":lat,
                         "Lng":lng,
                         "Max Temp":max_temp,
                         "Humidity":humidity,
                         "Cloudiness":cloudiness,
                         "Wind Speed":wind_speed,
                         "Country":country,
                         "Date":date})
                         

#show cities Dataframe
cities_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Bethel  41.37  -73.41 -401.3140        94          23        1.33
# 1      Darhan  49.49  105.92 -402.7720        92          80        1.09
# 2      Anshun  26.25  105.93 -350.6404        93         100        1.48
# 3       Rocha -34.48  -54.33 -378.2452        89          89        0.63
# 4  Luganville -15.53  167.17 -307.3540        74          75        4.10
# 5   Berezovyy  51.67  135.70 -388.8400        68         100        0.85
# 6   Busselton -33.65  115.33 -322.1284        45         100        4.56
# 7     Orgtrud  56.18   40.61 -392.7280        92           1        0.81
# 8   Upernavik  72.79  -56.15 -423.6052        96          99        1.71
# 9   Pergamino -33.89  -60.57 -365.3176        80           0        0.89
#
#   Country        Date
# 0      US  1604110450
# 1      MN  1604110621
# 2      CN  1604110621
# 3      UY  1604110553
# 4      VU  1604110621
# 5      RU  1604110621
# 6      AU  1604110621
# 7      RU  1604110621
# 8      GL  1604110621
# 9      AR  1604110622

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No City with a humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
#No City with a humidity > 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#No City with a humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature')
ax.scatter(cities_df['Lat'],cities_df['Max Temp'],edgecolors='red')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(cities_df['Lat'],cities_df['Humidity'],edgecolors='yellow')
plt.grid()
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(cities_df['Lat'],cities_df['Cloudiness'],edgecolors='blue')
plt.grid()
fig.savefig('lat_vs_cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(cities_df['Lat'],cities_df['Wind Speed'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_wind_speed.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
